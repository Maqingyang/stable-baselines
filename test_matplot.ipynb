# %%
import gym
import numpy as np
import cv2


from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
from stable_baselines import PPO1
# from particle_env import PrticleEnv
from particle_env_continuous import PrticleEnv

import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
env = PrticleEnv(alpha=1,win_thre=1,max_timestep=128)
env.reset()
env.render(mode='rgb_array')
# Out:
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# <ipython-input-12-5dc1345f1df4> in <module>
#       1 env = PrticleEnv(alpha=1,win_thre=1,max_timestep=128)
#       2 env.reset()
# ----> 3 env.render(mode='rgb_array')
#
# ~/project/stable-baselines/particle_env_continuous.py in render(self, mode, close)
#     112         cartheight = 30.0
#     113         if self.viewer is None:
# --> 114             from gym.envs.classic_control import rendering
#     115             self.viewer = rendering.Viewer(screen_width, screen_height)
#     116             # add goal
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in <module>
#      25
#      26 try:
# ---> 27     from pyglet.gl import *
#      28 except ImportError as e:
#      29     raise ImportError('''
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/gl/__init__.py in <module>
#     242     # trickery is for circular import
#     243     _pyglet.gl = _sys.modules[__name__]
# --> 244     import pyglet.window
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/window/__init__.py in <module>
#    1878 if not _is_pyglet_doc_run:
#    1879     pyglet.window = sys.modules[__name__]
# -> 1880     gl._create_shadow_window()
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     218
#     219     from pyglet.window import Window
# --> 220     _shadow_window = Window(width=1, height=1, visible=False)
#     221     _shadow_window.switch_to()
#     222
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     163                     self._event_handlers[message] = func
#     164
# --> 165         super(XlibWindow, self).__init__(*args, **kwargs)
#     166
#     167         global _can_detect_autorepeat
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     568
#     569         if not display:
# --> 570             display = pyglet.canvas.get_display()
#     571
#     572         if not screen:
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/canvas/__init__.py in get_display()
#      92
#      93     # Otherwise, create a new display and return it.
# ---> 94     return Display()
#      95
#      96
#
# ~/project/stable-baselines/venv/lib/python3.6/site-packages/pyglet/canvas/xlib.py in __init__(self, name, x_screen)
#     121         self._display = xlib.XOpenDisplay(name)
#     122         if not self._display:
# --> 123             raise NoSuchDisplayException('Cannot connect to "%s"' % name)
#     124
#     125         screen_count = xlib.XScreenCount(self._display)
#
# NoSuchDisplayException: Cannot connect to "None"

# %%
img = np.zeros((224,224,3))
plt.figure()
plt.imshow(img)
plt.show()
